# %%
import numpy as np
import matplotlib.pyplot as plt

class LTI_Continuous:
    def __init__(self, impulse_response):
        self.impulse_response = impulse_response
        self.INF = 1000
        
    def linear_combination_of_impulses(self, input_signal, delta):
        decomposed = []
        
        # Use np.arange to allow non-integer delta
        for i in np.arange(-self.INF, self.INF + 1, delta):
            coefficient = input_signal.get_value_at_time(i)
            
            if coefficient != 0:
                # Create unit impulse
                impulse = ContinuousSignal(unit_impulse)
                
                # Shift impulse by i
                shifted_impulse = impulse.shift_signal(i)
                                
                # Append the shifted impulse and its coefficient
                decomposed.append((shifted_impulse, coefficient, i))

        return decomposed
    
    def output_approx(self, signal, delta):
        # Create a new continuous signal with all values set to 0
        result = ContinuousSignal(lambda x: 0)
        
        # Decompose the input signal
        decomposed = self.linear_combination_of_impulses(signal, delta)
        
        # For each decomposed signal, compute the output
        for decomposed_signal, coefficient, i in decomposed:
            shifted_response = self.impulse_response.shift_signal(i)
            component = shifted_response.multiply_const_factor(coefficient)
            result = result.add(component)
        
        return result 
    
    def show(self):
        self.impulse_response.plot(-10, 10, 'Impulse Response')


# Example usage
def unit_impulse(x):
    delta = 0.5
    impulse = np.zeros_like(x)
    impulse[(x >= 0) & (x < delta)] = 1 / delta
    return impulse

# ContinuousSignal class (same as previous with vectorization fix)
class ContinuousSignal:
    def __init__(self, func):
        self.func = func
    
    def get_value_at_time(self, time):
        return self.func(time)
    
    def add(self, other):
        return ContinuousSignal(lambda x: np.vectorize(self.func)(x) + np.vectorize(other.func)(x))
    
    def shift_signal(self, shift):
        return ContinuousSignal(lambda x: np.vectorize(self.func)(x - shift))
    
    def multiply(self, other):
        return ContinuousSignal(lambda x: np.vectorize(self.func)(x) * np.vectorize(other.func)(x))
    
    def multiply_const_factor(self, scaler):
        return ContinuousSignal(lambda x: np.vectorize(self.func)(x) * scaler)
    
    def plot(self, start, end, label):
        x = np.linspace(start, end, 1000)
        y = self.func(x)
        plt.plot(x, y, label=label)
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.grid(True)
    
    @staticmethod
    def show():
        plt.legend()
        plt.show()


# Define input and impulse response signals
def myFunc(x):
    return np.sin(x)

signal = ContinuousSignal(myFunc)
response = ContinuousSignal(unit_impulse)

# Initialize the system
system = LTI_Continuous(response)

# Compute the output with non-integer delta
output = system.output_approx(signal, 0.5)

# Plot the output
output.plot(-10, 10, 'Output')
ContinuousSignal.show()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[1], line 102
#      99 output = system.output_approx(signal, 0.5)
#     101 # Plot the output
# --> 102 output.plot(-10, 10, 'Output')
#     103 ContinuousSignal.show()
#
# Cell In[1], line 76, in ContinuousSignal.plot(self, start, end, label)
#      74 def plot(self, start, end, label):
#      75     x = np.linspace(start, end, 1000)
# ---> 76     y = self.func(x)
#      77     plt.plot(x, y, label=label)
#      78     plt.xlabel('Time')
#
# Cell In[1], line 63, in ContinuousSignal.add.<locals>.<lambda>(x)
#      62 def add(self, other):
# ---> 63     return ContinuousSignal(lambda x: np.vectorize(self.func)(x) + np.vectorize(other.func)(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2470, in vectorize.__call__(self, *args, **kwargs)
#    2467     self._init_stage_2(*args, **kwargs)
#    2468     return self
# -> 2470 return self._call_as_normal(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2463, in vectorize._call_as_normal(self, *args, **kwargs)
#    2460     vargs = [args[_i] for _i in inds]
#    2461     vargs.extend([kwargs[_n] for _n in names])
# -> 2463 return self._vectorize_call(func=func, args=vargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2548, in vectorize._vectorize_call(self, func, args)
#    2546     res = func()
#    2547 else:
# -> 2548     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2550     # Convert args to object arrays first
#    2551     inputs = [asanyarray(a, dtype=object) for a in args]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2508, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2504     raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2505                      'unless `otypes` is set')
#    2507 inputs = [arg.flat[0] for arg in args]
# -> 2508 outputs = func(*inputs)
#    2510 # Performance note: profiling indicates that -- for simple
#    2511 # functions at least -- this wrapping can almost double the
#    2512 # execution time.
#    2513 # Hence we make it optional.
#    2514 if self.cache:
#
# Cell In[1], line 63, in ContinuousSignal.add.<locals>.<lambda>(x)
#      62 def add(self, other):
# ---> 63     return ContinuousSignal(lambda x: np.vectorize(self.func)(x) + np.vectorize(other.func)(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2470, in vectorize.__call__(self, *args, **kwargs)
#    2467     self._init_stage_2(*args, **kwargs)
#    2468     return self
# -> 2470 return self._call_as_normal(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2463, in vectorize._call_as_normal(self, *args, **kwargs)
#    2460     vargs = [args[_i] for _i in inds]
#    2461     vargs.extend([kwargs[_n] for _n in names])
# -> 2463 return self._vectorize_call(func=func, args=vargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2548, in vectorize._vectorize_call(self, func, args)
#    2546     res = func()
#    2547 else:
# -> 2548     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2550     # Convert args to object arrays first
#    2551     inputs = [asanyarray(a, dtype=object) for a in args]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2508, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2504     raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2505                      'unless `otypes` is set')
#    2507 inputs = [arg.flat[0] for arg in args]
# -> 2508 outputs = func(*inputs)
#    2510 # Performance note: profiling indicates that -- for simple
#    2511 # functions at least -- this wrapping can almost double the
#    2512 # execution time.
#    2513 # Hence we make it optional.
#    2514 if self.cache:
#
#     [... skipping similar frames: ContinuousSignal.add.<locals>.<lambda> at line 63 (492 times), vectorize.__call__ at line 2470 (492 times), vectorize._call_as_normal at line 2463 (492 times), vectorize._vectorize_call at line 2548 (492 times), vectorize._get_ufunc_and_otypes at line 2508 (491 times)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2508, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2504     raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2505                      'unless `otypes` is set')
#    2507 inputs = [arg.flat[0] for arg in args]
# -> 2508 outputs = func(*inputs)
#    2510 # Performance note: profiling indicates that -- for simple
#    2511 # functions at least -- this wrapping can almost double the
#    2512 # execution time.
#    2513 # Hence we make it optional.
#    2514 if self.cache:
#
# Cell In[1], line 63, in ContinuousSignal.add.<locals>.<lambda>(x)
#      62 def add(self, other):
# ---> 63     return ContinuousSignal(lambda x: np.vectorize(self.func)(x) + np.vectorize(other.func)(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2470, in vectorize.__call__(self, *args, **kwargs)
#    2467     self._init_stage_2(*args, **kwargs)
#    2468     return self
# -> 2470 return self._call_as_normal(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2463, in vectorize._call_as_normal(self, *args, **kwargs)
#    2460     vargs = [args[_i] for _i in inds]
#    2461     vargs.extend([kwargs[_n] for _n in names])
# -> 2463 return self._vectorize_call(func=func, args=vargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2548, in vectorize._vectorize_call(self, func, args)
#    2546     res = func()
#    2547 else:
# -> 2548     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2550     # Convert args to object arrays first
#    2551     inputs = [asanyarray(a, dtype=object) for a in args]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2503, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2496 else:
#    2497     # Get number of outputs and output types by calling the function on
#    2498     # the first entries of args.  We also cache the result to prevent
#    2499     # the subsequent call when the ufunc is evaluated.
#    2500     # Assumes that ufunc first evaluates the 0th elements in the input
#    2501     # arrays (the input values are not checked to ensure this)
#    2502     args = [asarray(arg) for arg in args]
# -> 2503     if builtins.any(arg.size == 0 for arg in args):
#    2504         raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2505                          'unless `otypes` is set')
#    2507     inputs = [arg.flat[0] for arg in args]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2503, in <genexpr>(.0)
#    2496 else:
#    2497     # Get number of outputs and output types by calling the function on
#    2498     # the first entries of args.  We also cache the result to prevent
#    2499     # the subsequent call when the ufunc is evaluated.
#    2500     # Assumes that ufunc first evaluates the 0th elements in the input
#    2501     # arrays (the input values are not checked to ensure this)
#    2502     args = [asarray(arg) for arg in args]
# -> 2503     if builtins.any(arg.size == 0 for arg in args):
#    2504         raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2505                          'unless `otypes` is set')
#    2507     inputs = [arg.flat[0] for arg in args]
#
# RecursionError: maximum recursion depth exceeded in comparison
